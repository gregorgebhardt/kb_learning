# %%
import ipympl
import kb_learning.plotting.notebook_plotter
from kb_learning.learner import ACRepsLearner
# %load_ext plot_work
# %set_experiment_class ACRepsLearner
# %matplotlib ipympl

# %cd ..
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d1203314aa9f> in <module>()
# ----> 1 import ipympl
#       2 import kb_learning.plotting.notebook_plotter
#       3 from kb_learning.learner import ACRepsLearner
#       4 get_ipython().run_line_magic('load_ext', 'plot_work')
#       5 get_ipython().run_line_magic('set_experiment_class', 'ACRepsLearner')
#
# ModuleNotFoundError: No module named 'ipympl'

# %%
# %load_experiment fixed_weight/fixed_weight.yml -e square -f kilobot w_factor0.0
len(experiments)
# Out:
# 1

# %%
# %restore_experiment_state -r 0 -i 0

# %%
experiment_instances
# Out:
# []

# %%
# %plot_iteration fixed_weight -r 0 -i 2 -f w_factor0 kilobot
# Out:
# [2018-04-05 19:09:30,174] [kb_learning] [INFO] restoring policy and kernel...
# [2018-04-05 19:09:30,181] [kb_learning] [INFO] restoring eval trajectories...
# [2018-04-05 19:09:30,303] [kb_learning] [INFO] pickling theta and lstd samples...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e967bc189c4b> in <module>()
# ----> 1 get_ipython().magic('plot_iteration fixed_weight -r 0 -i 2 -f w_factor0 kilobot')
#
# ~/bin/miniconda3/envs/gym_intel/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ~/bin/miniconda3/envs/gym_intel/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# ~/git/cluster_work/plot_work.py in plot_iteration(line)
#     100     for exp in filtered_experiments:
#     101             learner = __experiment_class.init_from_config(exp, args.repetition, args.iteration)
# --> 102             fw = __iteration_plot_functions[args.plotter_name](learner, exp, args.args)
#     103             clear_output()
#     104             if isinstance(fw, Figure):
#
# TypeError: plot_fixed_weight_iteration() takes 2 positional arguments but 3 were given

# %%
%
