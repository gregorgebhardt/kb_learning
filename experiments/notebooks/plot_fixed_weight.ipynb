# %%
import ipympl
import kb_learning.plotting.notebook_plotter
from kb_learning.learner import ACRepsLearner

# %load_ext plot_work
# %set_experiment_class ACRepsLearner
# %matplotlib ipympl

import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=[10, 10])

# %%
# %cd ..
# Out:
# /home/gebhardt/git/kb_learning/experiments

# %%
# %load_experiment fixed_weight/fixed_weight.yml -e square
# %plot_results mean_2std mean_sum_R

# %%
# %load_experiment ppo/ppo.yml -e eval_relative_env
# %plot_results mean_2std episode_reward_mean

# %%
# %restore_experiment_state -r 1 -i 20

# %%
# %plot_iteration fixed_weight samples
# Out:
# Accordion(children=(VBox(children=(Output(), Output(), Output(), Output())),), _titles={'0': 'square_sampling.…

# %%
plt.rc('figure', figsize=[9, 9])

# %%
plt.rcParams['figure.figsize']
# Out:
# [12.0, 12.0]
