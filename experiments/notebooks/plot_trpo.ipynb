# %%
import kb_learning.plotting.notebook_plotter
from kb_learning.learner import TRPOLearner
# %load_ext plot_work
# %set_experiment_class TRPOLearner

# %cd ..
# Out:
# /home/gebhardt/git/kb_learning/experiments

# %%
from jupyterthemes import jtplot
import matplotlib.pyplot as plt
# plt.rc('figure', figsize=[10, 5])
plt.rc('figure', max_open_warning=100)
plt.rc('savefig', format='svg')

jtplot.style(spines=False, gridlines=':', figsize=(20, 4))

# %%
# %load_experiment trpo/trpo.yml -e test
# %plot_results mean_2std episode_return_mean
# %plot_results mean_2std mean_entropy
# %plot_results mean_2std vf_loss
# %plot_results mean_2std ev_tdlam_before

# %%
# %restore_best_experiment_state episode_return_mean

# %%
for inst in experiment_instances:
    print("{} {} {}".format(inst._name, inst._rep, inst._it))
# Out:
# test 0 39
